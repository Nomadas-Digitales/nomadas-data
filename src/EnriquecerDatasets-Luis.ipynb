# %% [markdown]
# <a id="inicio"></a>
# # Enriquecer Datasets
#
#
# 1. [Importar librerías](#import)
# 2. [Definición de Constantes](#constants)
# 3. [ Enriquecer Dataset de Idealista](#enriquecer_idealista)
#    - [Añadir y renombrar campos](#add_ren_fields)
#    - [Asignar distancia a playa](#distancia_playa)
#    - [Enriquecer con otros campos](#otros_campos)
#      - [internet](#internet)
#      - [zonaTranquila](#zona_tranquila)
#
# Proximos pasos:
# 1. Ejecutar las celdas de importación de librerías y definición de contantes
# 2. Continuar por [Enriquecer con otros campos](#otros_campos)

# %% [markdown]
#  <a id="import"></a>
# ## Importar librerías

# %%
import os
import sys
sys.path.append(r"../")

import numpy as np
import pandas as pd
from math import sin, cos, sqrt, atan2, radians

# %% [markdown]
#  <a id="constants"></a>
# ## Definición de Constantes

# %%
DATA_PATH = "data"

# %% [markdown]
#  <a id="enriquecer_idealista"></a>
# ## Enriquecer Dataset de Idealista

# %%
idealista_val_df = pd.read_csv(os.path.join(DATA_PATH, 'idealista_alquiler_valencia_clean.csv'))
idealista_val_df
# Out:
#       propertyCode                            address  province municipality  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia     Valencia
# 1         95768330                Juan Bautista Comes  Valencia     Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia     Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia     Valencia
# 4         95720789                  barrio La Petxina  Valencia     Valencia
# ...            ...                                ...       ...          ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia     Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia     Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia     Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia     Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia     Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  floor  price propertyType  size  exterior  rooms  bathrooms  \
# 0         2645      0    500         flat    52      True      2          1
# 1         3178      3    490         flat    76      True      2          1
# 2         3485      3    650         flat    60     False      2          1
# 3         2066      5    730         flat    75      True      2          1
# 4         1110      3    720         flat    80      True      3          1
# ...        ...    ...    ...          ...   ...       ...    ...        ...
# 1102      1797      4    975         flat   100      True      2          2
# 1103       193      4   1300         flat    85      True      3          2
# 1104      2061      4    900         flat    95      True      3          2
# 1105      1048      2    800         flat    90      True      2          1
# 1106       844      7   1600       duplex    87      True      2          2
#
#      status  hasLift
# 0      good     True
# 1      good    False
# 2      good    False
# 3      good     True
# 4      good    False
# ...     ...      ...
# 1102   good     True
# 1103   good     True
# 1104   good     True
# 1105   good    False
# 1106   good     True
#
# [1107 rows x 19 columns]

# %% [markdown]
#  <a id="add_ren_fields"></a>
# ### Añadir y renombrar campos

# %%
idealista_val_df.rename(columns={"municipality": "city"},
           inplace=True)
idealista_val_df["idCity"] = 1

# %%
idealista_val_df
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  floor  price propertyType  size  exterior  rooms  bathrooms  \
# 0         2645      0    500         flat    52      True      2          1
# 1         3178      3    490         flat    76      True      2          1
# 2         3485      3    650         flat    60     False      2          1
# 3         2066      5    730         flat    75      True      2          1
# 4         1110      3    720         flat    80      True      3          1
# ...        ...    ...    ...          ...   ...       ...    ...        ...
# 1102      1797      4    975         flat   100      True      2          2
# 1103       193      4   1300         flat    85      True      3          2
# 1104      2061      4    900         flat    95      True      3          2
# 1105      1048      2    800         flat    90      True      2          1
# 1106       844      7   1600       duplex    87      True      2          2
#
#      status  hasLift  idCity
# 0      good     True       1
# 1      good    False       1
# 2      good    False       1
# 3      good     True       1
# 4      good    False       1
# ...     ...      ...     ...
# 1102   good     True       1
# 1103   good     True       1
# 1104   good     True       1
# 1105   good    False       1
# 1106   good     True       1
#
# [1107 rows x 20 columns]

# %%
idealista_val_df.to_csv(os.path.join(DATA_PATH, 'home_valencia.csv'), index=False)

# %% [markdown]
#  <a id="distancia_playa"></a>
# ### Asignar distancia a playa

# %%
home_valencia_df = pd.read_csv(os.path.join(DATA_PATH, 'home_valencia.csv'))
home_valencia_df
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  floor  price propertyType  size  exterior  rooms  bathrooms  \
# 0         2645      0    500         flat    52      True      2          1
# 1         3178      3    490         flat    76      True      2          1
# 2         3485      3    650         flat    60     False      2          1
# 3         2066      5    730         flat    75      True      2          1
# 4         1110      3    720         flat    80      True      3          1
# ...        ...    ...    ...          ...   ...       ...    ...        ...
# 1102      1797      4    975         flat   100      True      2          2
# 1103       193      4   1300         flat    85      True      3          2
# 1104      2061      4    900         flat    95      True      3          2
# 1105      1048      2    800         flat    90      True      2          1
# 1106       844      7   1600       duplex    87      True      2          2
#
#      status  hasLift  idCity
# 0      good     True       1
# 1      good    False       1
# 2      good    False       1
# 3      good     True       1
# 4      good    False       1
# ...     ...      ...     ...
# 1102   good     True       1
# 1103   good     True       1
# 1104   good     True       1
# 1105   good    False       1
# 1106   good     True       1
#
# [1107 rows x 20 columns]

# %%
def distance(longitud1, latitud1, longitud2, latitud2):
    '''
    Calcula la distancia en metros entre 2 coordenadas longitud/latitud.

    Parametros:
    * longitud1, latitud1: coordenada 1
    * longitud2, latitud2: coordenada 2
    Resultado:
    * Distancia en metros
    '''
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(latitud1)
    lon1 = radians(longitud1)
    lat2 = radians(latitud2)
    lon2 = radians(longitud2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c * 1000

    return distance

# %%
home_valencia_df["distanceBeach"] = 0

# %%
def calcular_dist_a_playa(row):
    #print("longitude:", row['longitude'], "latitude:", row['latitude'])
    distancia = distance(playa_lon, playa_lat, row['longitude'], row['latitude'])
    # print("Distancia a playa:", int(distancia))
    row['distanceBeach'] = int(distancia)
    
    return row

# %%
playa_lat= 39.483709
playa_lon= -0.324952

# %%
home_valencia_df = home_valencia_df.apply(calcular_dist_a_playa, axis = 1)
home_valencia_df
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  ...  price  propertyType size  exterior  rooms  bathrooms  \
# 0         2645  ...    500          flat   52      True      2          1
# 1         3178  ...    490          flat   76      True      2          1
# 2         3485  ...    650          flat   60     False      2          1
# 3         2066  ...    730          flat   75      True      2          1
# 4         1110  ...    720          flat   80      True      3          1
# ...        ...  ...    ...           ...  ...       ...    ...        ...
# 1102      1797  ...    975          flat  100      True      2          2
# 1103       193  ...   1300          flat   85      True      3          2
# 1104      2061  ...    900          flat   95      True      3          2
# 1105      1048  ...    800          flat   90      True      2          1
# 1106       844  ...   1600        duplex   87      True      2          2
#
#       status hasLift  idCity  distanceBeach
# 0       good    True       1           6246
# 1       good   False       1           7846
# 2       good   False       1           2564
# 3       good    True       1           6687
# 4       good   False       1           5724
# ...      ...     ...     ...            ...
# 1102    good    True       1           3241
# 1103    good    True       1           4530
# 1104    good    True       1           6065
# 1105    good   False       1           5682
# 1106    good    True       1           3899
#
# [1107 rows x 21 columns]

# %%
home_valencia_df.dtypes
# Out:
# propertyCode       int64
# address           object
# province          object
# city              object
# district          object
# country           object
# neighborhood      object
# latitude         float64
# longitude        float64
# distance           int64
# floor              int64
# price              int64
# propertyType      object
# size               int64
# exterior            bool
# rooms              int64
# bathrooms          int64
# status            object
# hasLift             bool
# idCity             int64
# distanceBeach      int64
# dtype: object

# %%
home_valencia_df.to_csv(os.path.join(DATA_PATH, 'home_valencia.csv'), index=False)

# %% [markdown]
#  <a id="otros_campos"></a>
# ### Enriquecer con otros campos
#
# - internet: velocidad media de conexión a internet en Mbps
# - safety: nivel de seguridad de la zona conde está la vivienda (de 0 a 5)
# - zonaTranquila: indica si la vivienda está en una zona tranquila o no (está en zona bulliciosa)
# - score: valoración de la vivienda (0 a 5)
#
# Guardar el resultado en el fichero **home_valencia_luis.csv** para no machacar el fichero **home_valencia.csv**.

# %%
home_valencia_df = pd.read_csv(os.path.join(DATA_PATH, 'home_valencia.csv'))
home_valencia_df
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  ...  price  propertyType size  exterior  rooms  bathrooms  \
# 0         2645  ...    500          flat   52      True      2          1
# 1         3178  ...    490          flat   76      True      2          1
# 2         3485  ...    650          flat   60     False      2          1
# 3         2066  ...    730          flat   75      True      2          1
# 4         1110  ...    720          flat   80      True      3          1
# ...        ...  ...    ...           ...  ...       ...    ...        ...
# 1102      1797  ...    975          flat  100      True      2          2
# 1103       193  ...   1300          flat   85      True      3          2
# 1104      2061  ...    900          flat   95      True      3          2
# 1105      1048  ...    800          flat   90      True      2          1
# 1106       844  ...   1600        duplex   87      True      2          2
#
#       status hasLift  idCity  distanceBeach
# 0       good    True       1           6246
# 1       good   False       1           7846
# 2       good   False       1           2564
# 3       good    True       1           6687
# 4       good   False       1           5724
# ...      ...     ...     ...            ...
# 1102    good    True       1           3241
# 1103    good    True       1           4530
# 1104    good    True       1           6065
# 1105    good   False       1           5682
# 1106    good    True       1           3899
#
# [1107 rows x 21 columns]

# %%
# Número de viviendas por distrito
count_districts = home_valencia_df[['district','idCity']].groupby('district').count()
count_districts.rename(columns={"idCity": "count"}, inplace=True)
count_districts
# Out:
#                   count
# district
# Algirós              26
# Benicalap            36
# Benimaclet           29
# Camins al Grau       76
# Campanar             47
# Ciutat Vella        215
# El Pla del Real      42
# Extramurs            89
# Jesús                39
# L'Eixample           86
# L'Olivereta          75
# La Saïdia            42
# Patraix              34
# Poblats Marítims    135
# Quatre Carreres      71
# Rascanya             65

# %%
# Número de viviendas por barrio
count_districts = home_valencia_df[['neighborhood','idCity']].groupby('neighborhood').count()
count_districts.rename(columns={"idCity": "count"}, inplace=True)
count_districts
# Out:
#                   count
# neighborhood
# Aiora                17
# Albors               10
# Arrancapins          25
# Barrio de Favara      6
# Benicalap            21
# ...                 ...
# Tormos                5
# Torrefiel            29
# Tres Forques          6
# Trinitat             15
# Vara de Quart         8
#
# [71 rows x 1 columns]

# %% [markdown]
# <a id="internet"></a>
# #### internet
#
# - **avg_d_kbps**: The average download speed of all tests performed in the tile, represented in kilobits per second.
# - **avg_u_kbps**: The average upload speed of all tests performed in the tile, represented in kilobits per second.
#
# Elegimos la velocidad de descarga (*avg_d_kbps*) para rellenar el campo internet.

# %%
home_valencia_internet_df = pd.read_csv(os.path.join(DATA_PATH, 'home_valencia_internet.csv'), sep=';')
home_valencia_internet_df
# Out:
#       OID_  propertyCode  avg_d_kbps  avg_u_kbps
# 0        1      93713058      185508      114934
# 1        2      95768330      194247      148438
# 2        3      95768462      223844      163182
# 3        4      95767951      257302      168351
# 4        5      95720789      184069      140924
# ...    ...           ...         ...         ...
# 1102  1103      95406717      112127      110267
# 1103  1104      90295626      121951       99378
# 1104  1105      95333382      232177      148718
# 1105  1106      95255561      182093      149480
# 1106  1107      94811135      146537      107343
#
# [1107 rows x 4 columns]

# %%
home_valencia_internet_df[['propertyCode','avg_d_kbps']]
# Out:
#       propertyCode  avg_d_kbps
# 0         93713058      185508
# 1         95768330      194247
# 2         95768462      223844
# 3         95767951      257302
# 4         95720789      184069
# ...            ...         ...
# 1102      95406717      112127
# 1103      90295626      121951
# 1104      95333382      232177
# 1105      95255561      182093
# 1106      94811135      146537
#
# [1107 rows x 2 columns]

# %%
home_valencia_df_lrg = pd.merge(home_valencia_df, home_valencia_internet_df[['propertyCode','avg_d_kbps']], left_on = 'propertyCode', right_on = 'propertyCode')

# %%
home_valencia_df_lrg.rename(columns={"avg_d_kbps": "internet"}, inplace=True)
home_valencia_df_lrg["internet"] = home_valencia_df_lrg["internet"].apply(lambda x: round(x/1000))
home_valencia_df_lrg.dtypes
# Out:
# propertyCode       int64
# address           object
# province          object
# city              object
# district          object
# country           object
# neighborhood      object
# latitude         float64
# longitude        float64
# distance           int64
# floor              int64
# price              int64
# propertyType      object
# size               int64
# exterior            bool
# rooms              int64
# bathrooms          int64
# status            object
# hasLift             bool
# idCity             int64
# distanceBeach      int64
# internet           int64
# dtype: object

# %%
home_valencia_df_lrg
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  ...  propertyType  size exterior  rooms  bathrooms  status  \
# 0         2645  ...          flat    52     True      2          1    good
# 1         3178  ...          flat    76     True      2          1    good
# 2         3485  ...          flat    60    False      2          1    good
# 3         2066  ...          flat    75     True      2          1    good
# 4         1110  ...          flat    80     True      3          1    good
# ...        ...  ...           ...   ...      ...    ...        ...     ...
# 1102      1797  ...          flat   100     True      2          2    good
# 1103       193  ...          flat    85     True      3          2    good
# 1104      2061  ...          flat    95     True      3          2    good
# 1105      1048  ...          flat    90     True      2          1    good
# 1106       844  ...        duplex    87     True      2          2    good
#
#       hasLift idCity  distanceBeach  internet
# 0        True      1           6246       186
# 1       False      1           7846       194
# 2       False      1           2564       224
# 3        True      1           6687       257
# 4       False      1           5724       184
# ...       ...    ...            ...       ...
# 1102     True      1           3241       112
# 1103     True      1           4530       122
# 1104     True      1           6065       232
# 1105    False      1           5682       182
# 1106     True      1           3899       147
#
# [1107 rows x 22 columns]

# %% [markdown]
# <a id="zona_tranquila"></a>
# #### zonaTranquila

# %%
home_valencia_nruido_df = pd.read_csv(os.path.join(DATA_PATH, 'home_valencia_nivel_ruido.csv'), sep=';')
home_valencia_nruido_df
# Out:
#       OID_  propertyCode  nivelruido
# 0        1      93713058           1
# 1        2      95768330           3
# 2        3      95768462           3
# 3        4      95767951           2
# 4        5      95720789           2
# ...    ...           ...         ...
# 1102  1103      95406717           3
# 1103  1104      90295626           1
# 1104  1105      95333382           3
# 1105  1106      95255561           1
# 1106  1107      94811135           2
#
# [1107 rows x 3 columns]

# %%
home_valencia_nruido_df.dtypes
# Out:
# OID_            int64
# propertyCode    int64
# nivelruido      int64
# dtype: object

# %%
home_valencia_nruido_df["nivelruido"].unique()
# Out:
# array([1, 3, 2, 4, 5, 6], dtype=int64)

# %%
home_valencia_nruido_df["zonaTranquila"] = np.where(home_valencia_nruido_df["nivelruido"] < 3, True, False)
home_valencia_nruido_df
# Out:
#       OID_  propertyCode  nivelruido  zonaTranquila
# 0        1      93713058           1           True
# 1        2      95768330           3          False
# 2        3      95768462           3          False
# 3        4      95767951           2           True
# 4        5      95720789           2           True
# ...    ...           ...         ...            ...
# 1102  1103      95406717           3          False
# 1103  1104      90295626           1           True
# 1104  1105      95333382           3          False
# 1105  1106      95255561           1           True
# 1106  1107      94811135           2           True
#
# [1107 rows x 4 columns]

# %%
home_valencia_df_lrg = pd.merge(home_valencia_df_lrg, home_valencia_nruido_df[['propertyCode','zonaTranquila']], left_on = 'propertyCode', right_on = 'propertyCode')

# %%
home_valencia_df_lrg
# Out:
#       propertyCode                            address  province      city  \
# 0         93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1         95768330                Juan Bautista Comes  Valencia  Valencia
# 2         95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3         95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4         95720789                  barrio La Petxina  Valencia  Valencia
# ...            ...                                ...       ...       ...
# 1102      95406717            Calle d'Alvaro de Bazan  Valencia  Valencia
# 1103      90295626              Plaza de l'Ajuntament  Valencia  Valencia
# 1104      95333382  Calle de la Pianista Empar Iturbi  Valencia  Valencia
# 1105      95255561       Calle del Pintor Vila Prades  Valencia  Valencia
# 1106      94811135            barrio El Pla del Remei  Valencia  Valencia
#
#              district country      neighborhood   latitude  longitude  \
# 0           Benicalap  España         Benicalap  39.489125  -0.397384
# 1         L'Olivereta  España           La Llum  39.467968  -0.414041
# 2      Camins al Grau  España             Aiora  39.462984  -0.338028
# 3         L'Olivereta  España         Nou Moles  39.471763  -0.401295
# 4           Extramurs  España        La Petxina  39.472529  -0.390041
# ...               ...     ...               ...        ...        ...
# 1102  El Pla del Real  España        Jaume Roig  39.482761  -0.362692
# 1103     Ciutat Vella  España     Sant Francesc  39.472340  -0.375630
# 1104            Jesús  España         La Raiosa  39.453232  -0.383522
# 1105        Extramurs  España        La Petxina  39.472059  -0.389390
# 1106       L'Eixample  España  El Pla del Remei  39.471238  -0.367402
#
#       distance  ...  size  exterior rooms  bathrooms  status  hasLift  idCity  \
# 0         2645  ...    52      True     2          1    good     True       1
# 1         3178  ...    76      True     2          1    good    False       1
# 2         3485  ...    60     False     2          1    good    False       1
# 3         2066  ...    75      True     2          1    good     True       1
# 4         1110  ...    80      True     3          1    good    False       1
# ...        ...  ...   ...       ...   ...        ...     ...      ...     ...
# 1102      1797  ...   100      True     2          2    good     True       1
# 1103       193  ...    85      True     3          2    good     True       1
# 1104      2061  ...    95      True     3          2    good     True       1
# 1105      1048  ...    90      True     2          1    good    False       1
# 1106       844  ...    87      True     2          2    good     True       1
#
#      distanceBeach  internet  zonaTranquila
# 0             6246       186           True
# 1             7846       194          False
# 2             2564       224          False
# 3             6687       257           True
# 4             5724       184           True
# ...            ...       ...            ...
# 1102          3241       112          False
# 1103          4530       122           True
# 1104          6065       232          False
# 1105          5682       182           True
# 1106          3899       147           True
#
# [1107 rows x 23 columns]

# %%
home_valencia_df_lrg.to_csv(os.path.join(DATA_PATH, 'home_valencia_luis.csv'), index=False)

# %% [markdown]
# [Ir a inicio](#inicio)
