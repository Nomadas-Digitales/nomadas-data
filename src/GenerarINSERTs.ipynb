# %% [markdown]
# <a id="inicio"></a>
# # Generar sentencias INSERTs
#
#
# 1. [Importar librerías](#import)
# 2. [Definición de Constantes](#constants)

# %% [markdown]
#  <a id="import"></a>
# ## Importar librerías

# %%
import os
import sys
sys.path.append(r"../")

import numpy as np
import pandas as pd

# %% [markdown]
#  <a id="constants"></a>
# ## Definición de Constantes

# %%
DATA_PATH = "data"

# %% [markdown]
# ## Generar INSERTs tabla Home
#
# Esctructura de la tabla:
#
# CREATE TABLE IF NOT EXISTS home (
#   **propertyCode** INTEGER PRIMARY KEY,
#   **idCity** INTEGER references city(idCity),
#   **address** VARCHAR(100),
#   **district** VARCHAR(50),
#   **neighborhood** VARCHAR(50),
#   **latitude** NUMERIC(18,7),
#   **longitude** NUMERIC(18,7),
#   **distance** INTEGER,
#   **distanceBeach** INTEGER,
#   **distanceCoworking** INTEGER,
#   **floor** SMALLINT,
#   **price** SMALLINT,
#   **propertyType** VARCHAR(50),
#   **size** SMALLINT,
#   **exterior** BOOLEAN,
#   **rooms** SMALLINT,
#   **bathrooms** SMALLINT,
#   **status** VARCHAR(50),
#   **haslift** BOOLEAN,
#   **internet** SMALLINT,
#   **safety** SMALLINT,
#   **zonaTranquila** BOOLEAN,
#   **score** INTEGER,
#   **available** BOOLEAN
# );
#
# 23 columnas.

# %%
home_valencia_df = pd.read_csv(os.path.join(DATA_PATH, 'home_valencia_luis.csv'))
display(home_valencia_df.columns)
home_valencia_df.head()
# Out:
# Index(['propertyCode', 'address', 'province', 'city', 'district', 'country',
#        'neighborhood', 'latitude', 'longitude', 'distance', 'floor', 'price',
#        'propertyType', 'size', 'exterior', 'rooms', 'bathrooms', 'status',
#        'hasLift', 'idCity', 'distanceBeach', 'internet', 'zonaTranquila'],
#       dtype='object')
#    propertyCode                            address  province      city  \
# 0      93713058      Calle Doctor Nicasio Benlloch  Valencia  Valencia
# 1      95768330                Juan Bautista Comes  Valencia  Valencia
# 2      95768462           Calle de Felipe Salvador  Valencia  Valencia
# 3      95767951  Calle de la Democracia, Nou Moles  Valencia  Valencia
# 4      95720789                  barrio La Petxina  Valencia  Valencia
#
#          district country neighborhood   latitude  longitude  distance  ...  \
# 0       Benicalap  España    Benicalap  39.489125  -0.397384      2645  ...
# 1     L'Olivereta  España      La Llum  39.467968  -0.414041      3178  ...
# 2  Camins al Grau  España        Aiora  39.462984  -0.338028      3485  ...
# 3     L'Olivereta  España    Nou Moles  39.471763  -0.401295      2066  ...
# 4       Extramurs  España   La Petxina  39.472529  -0.390041      1110  ...
#
#    size  exterior rooms  bathrooms  status  hasLift  idCity distanceBeach  \
# 0    52      True     2          1    good     True       1          6246
# 1    76      True     2          1    good    False       1          7846
# 2    60     False     2          1    good    False       1          2564
# 3    75      True     2          1    good     True       1          6687
# 4    80      True     3          1    good    False       1          5724
#
#    internet  zonaTranquila
# 0       186           True
# 1       194          False
# 2       224          False
# 3       257           True
# 4       184           True
#
# [5 rows x 23 columns]

# %%
# Borrar las columnas del DataSet que no se necesitan
cols_borrar = ['city', 'province', 'country']
home_valencia_df.drop(columns = cols_borrar, inplace = True)

# %%
# CELDA OPCIONAL: Ejecutar mientras no existan estas columnas en el dataset:
# distanceCoworking, safety, score, available
home_valencia_df['distanceCoworking'] = 3000
home_valencia_df['safety'] = np.random.randint(1, 5, home_valencia_df.shape[0], np.int64)
home_valencia_df['score'] = np.random.randint(2, 5, home_valencia_df.shape[0], np.int64)
home_valencia_df['available'] = True

# %%
home_valencia_df.dtypes
# Out:
# propertyCode           int64
# address               object
# district              object
# neighborhood          object
# latitude             float64
# longitude            float64
# distance               int64
# floor                  int64
# price                  int64
# propertyType          object
# size                   int64
# exterior                bool
# rooms                  int64
# bathrooms              int64
# status                object
# hasLift                 bool
# idCity                 int64
# distanceBeach          int64
# internet               int64
# zonaTranquila           bool
# distanceCoworking      int64
# safety                 int64
# score                  int64
# available               bool
# dtype: object

# %%
idValencia = 1
home_valencia_df['idCity'] = idValencia

# %%
home_valencia_df
# Out:
#       propertyCode                            address         district  \
# 0         93713058      Calle Doctor Nicasio Benlloch        Benicalap
# 1         95768330                Juan Bautista Comes      L'Olivereta
# 2         95768462           Calle de Felipe Salvador   Camins al Grau
# 3         95767951  Calle de la Democracia, Nou Moles      L'Olivereta
# 4         95720789                  barrio La Petxina        Extramurs
# ...            ...                                ...              ...
# 1102      95406717            Calle d'Alvaro de Bazan  El Pla del Real
# 1103      90295626              Plaza de l'Ajuntament     Ciutat Vella
# 1104      95333382  Calle de la Pianista Empar Iturbi            Jesús
# 1105      95255561       Calle del Pintor Vila Prades        Extramurs
# 1106      94811135            barrio El Pla del Remei       L'Eixample
#
#           neighborhood   latitude  longitude  distance  floor  price  \
# 0            Benicalap  39.489125  -0.397384      2645      0    500
# 1              La Llum  39.467968  -0.414041      3178      3    490
# 2                Aiora  39.462984  -0.338028      3485      3    650
# 3            Nou Moles  39.471763  -0.401295      2066      5    730
# 4           La Petxina  39.472529  -0.390041      1110      3    720
# ...                ...        ...        ...       ...    ...    ...
# 1102        Jaume Roig  39.482761  -0.362692      1797      4    975
# 1103     Sant Francesc  39.472340  -0.375630       193      4   1300
# 1104         La Raiosa  39.453232  -0.383522      2061      4    900
# 1105        La Petxina  39.472059  -0.389390      1048      2    800
# 1106  El Pla del Remei  39.471238  -0.367402       844      7   1600
#
#      propertyType  ...  status  hasLift  idCity  distanceBeach internet  \
# 0            flat  ...    good     True       1           6246      186
# 1            flat  ...    good    False       1           7846      194
# 2            flat  ...    good    False       1           2564      224
# 3            flat  ...    good     True       1           6687      257
# 4            flat  ...    good    False       1           5724      184
# ...           ...  ...     ...      ...     ...            ...      ...
# 1102         flat  ...    good     True       1           3241      112
# 1103         flat  ...    good     True       1           4530      122
# 1104         flat  ...    good     True       1           6065      232
# 1105         flat  ...    good    False       1           5682      182
# 1106       duplex  ...    good     True       1           3899      147
#
#       zonaTranquila  distanceCoworking  safety  score  available
# 0              True               3000       1      3       True
# 1             False               3000       4      2       True
# 2             False               3000       1      2       True
# 3              True               3000       2      2       True
# 4              True               3000       1      2       True
# ...             ...                ...     ...    ...        ...
# 1102          False               3000       1      3       True
# 1103           True               3000       1      4       True
# 1104          False               3000       2      2       True
# 1105           True               3000       3      2       True
# 1106           True               3000       3      2       True
#
# [1107 rows x 24 columns]

# %%
sql_inserts = []

colums = ', '.join(home_valencia_df.columns)
print(colums)
for index, row in home_valencia_df.iterrows():
    #display(row)
    sql_inserts.append("INSERT INTO home (" + colums + ") VALUES " + str(tuple(row.values)))

sql_inserts
# Out:
# propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available
# ["INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93713058, 'Calle Doctor Nicasio Benlloch', 'Benicalap', 'Benicalap', 39.4891251, -0.3973836, 2645, 0, 500, 'flat', 52, True, 2, 1, 'good', True, 1, 6246, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95768330, \'Juan Bautista Comes\', "L\'Olivereta", \'La Llum\', 39.4679683, -0.4140414, 3178, 3, 490, \'flat\', 76, True, 2, 1, \'good\', False, 1, 7846, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95768462, 'Calle de Felipe Salvador', 'Camins al Grau', 'Aiora', 39.4629836, -0.3380281, 3485, 3, 650, 'flat', 60, False, 2, 1, 'good', False, 1, 2564, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95767951, \'Calle de la Democracia, Nou Moles\', "L\'Olivereta", \'Nou Moles\', 39.4717632, -0.4012954999999999, 2066, 5, 730, \'flat\', 75, True, 2, 1, \'good\', True, 1, 6687, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95720789, 'barrio La Petxina', 'Extramurs', 'La Petxina', 39.4725289, -0.3900405999999999, 1110, 3, 720, 'flat', 80, True, 3, 1, 'good', False, 1, 5724, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95726855, 'barrio El Mercat', 'Ciutat Vella', 'El Mercat', 39.4735918, -0.3803346999999999, 382, 1, 1000, 'flat', 90, True, 3, 2, 'good', False, 1, 4886, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95599661, 'barrio Malilla', 'Quatre Carreres', 'Malilla', 39.4489341, -0.3781703999999999, 2468, 6, 900, 'flat', 70, True, 2, 1, 'good', False, 1, 5987, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95767501, \'Calle Santos Justo y Pastor\', \'Algirós\', "L\'Illa Perduda", 39.4664176, -0.3433990999999999, 2951, 3, 600, \'flat\', 67, True, 2, 1, \'good\', True, 1, 2491, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95767433, 'av malvarosa, 20', 'Poblats Marítims', 'Playa de la Malvarrosa', 39.4778758, -0.3278585, 4304, 2, 650, 'flat', 80, True, 3, 1, 'good', False, 1, 695, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95600514, 'barrio Sant Francesc', 'Ciutat Vella', 'Sant Francesc', 39.4694075, -0.3765881, 198, 1, 800, 'flat', 70, True, 2, 1, 'good', False, 1, 4710, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95599612, \'barrio Russafa\', "L\'Eixample", \'Russafa\', 39.4610436, -0.3682018999999999, 1362, 2, 800, \'flat\', 80, True, 2, 1, \'good\', False, 1, 4488, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95302774, 'barrio Campanar', 'Campanar', 'Campanar', 39.482768, -0.3905289999999999, 1725, 4, 1200, 'flat', 100, True, 3, 2, 'good', False, 1, 5630, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95234995, 'barrio En Corts', 'Quatre Carreres', 'En Corts', 39.4542964, -0.3739655, 1891, 5, 900, 'flat', 70, True, 2, 1, 'good', False, 1, 5330, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95659654, 'barrio El Carme', 'Ciutat Vella', 'El Carme', 39.4764912, -0.3827694, 762, 5, 960, 'penthouse', 80, True, 2, 2, 'good', False, 1, 5028, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91679352, 'Francisco Cubells, 10  ', 'Poblats Marítims', 'El Grau', 39.4632642, -0.3342127, 3795, 3, 599, 'flat', 66, True, 3, 1, 'good', True, 1, 2409, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95302409, 'barrio El Cabanyal-El Canyamelar', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4713938, -0.3267359999999999, 4334, 2, 950, 'flat', 90, True, 4, 2, 'good', True, 1, 1378, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95320802, 'barrio La Creu Coberta', 'Jesús', 'La Creu Coberta', 39.4527742, -0.3858569, 2170, 2, 650, 'flat', 70, True, 2, 1, 'good', True, 1, 6260, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95302103, 'barrio Benimaclet', 'Benimaclet', 'Benimaclet', 39.4878381, -0.3577346999999999, 2501, 1, 700, 'flat', 90, True, 2, 1, 'good', False, 1, 2851, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95163599, 'barrio Benicalap', 'Benicalap', 'Benicalap', 39.4926192, -0.3916506999999999, 2691, 4, 900, 'flat', 80, True, 3, 1, 'good', False, 1, 5810, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95766665, 'barrio Sant Francesc', 'Ciutat Vella', 'Sant Francesc', 39.4703238, -0.3760593, 134, 4, 875, 'penthouse', 55, True, 1, 1, 'renew', True, 1, 4633, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95766638, 'Avenida Valladolid, 3', 'Rascanya', 'Sant Llorenç', 39.4898011, -0.3635701, 2385, 9, 800, 'flat', 75, True, 2, 2, 'good', True, 1, 3383, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (33924117, 'Avenida del Cardenal Benlloch', 'El Pla del Real', 'Mestalla', 39.473796, -0.354981, 1933, 1, 700, 'flat', 70, True, 3, 1, 'good', True, 1, 2803, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95464308, 'Calle San Vicente Mártir', 'Ciutat Vella', 'Sant Francesc', 39.4733041, -0.3765721999999999, 249, 3, 1350, 'flat', 98, True, 2, 1, 'good', True, 1, 4580, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95449159, 'Calle de Colón', 'Ciutat Vella', 'Sant Francesc', 39.4666807, -0.3743516, 552, 8, 1000, 'flat', 50, True, 2, 1, 'good', True, 1, 4645, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95765238, 'Avenida del Primado Reig, 113', 'La Saïdia', 'Trinitat', 39.4851233, -0.3642094999999999, 1916, 4, 690, 'flat', 54, True, 1, 1, 'good', True, 1, 3373, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95763674, 'barrio En Corts', 'Quatre Carreres', 'En Corts', 39.4576954, -0.3725974999999999, 1545, 3, 625, 'flat', 100, False, 2, 1, 'good', True, 1, 5010, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95761970, \'Calle de Pere de València\', \'Algirós\', "L\'Illa Perduda", 39.4667836, -0.3371195999999999, 3477, 3, 900, \'flat\', 97, True, 4, 1, \'good\', True, 1, 2153, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95761969, 'Calle de la Puebla de Valverde, 7', 'Patraix', 'Vara de Quart', 39.4601459, -0.4020354, 2453, 6, 650, 'flat', 66, True, 3, 1, 'good', True, 1, 7118, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95761772, 'barrio Sant Llorenç', 'Rascanya', 'Sant Llorenç', 39.4942034, -0.3629384, 2844, 9, 890, 'flat', 100, True, 3, 2, 'good', True, 1, 3463, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (86741556, 'barrio Ciutat Fallera', 'Benicalap', 'Ciutat Fallera', 39.4959612, -0.397592, 3267, 4, 580, 'flat', 80, False, 3, 1, 'good', True, 1, 6382, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95761479, 'Calle de Dolores Marqués', 'Benimaclet', 'Benimaclet', 39.4877724, -0.3638164, 2180, 5, 650, 'flat', 61, False, 2, 1, 'good', True, 1, 3366, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88099280, 'barrio Mestalla', 'El Pla del Real', 'Mestalla', 39.4710528, -0.3572133999999999, 1718, 7, 1150, 'flat', 60, True, 2, 1, 'good', True, 1, 3107, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95759210, 'barrio Tormos', 'La Saïdia', 'Tormos', 39.4853826, -0.3786052, 1589, 0, 800, 'flat', 81, True, 3, 1, 'good', True, 1, 4609, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95756481, 'Gran Via Fernando el Católico, 70', 'Extramurs', 'El Botànic', 39.4748195, -0.3878879999999999, 1002, 0, 1200, 'flat', 84, False, 3, 2, 'good', True, 1, 5492, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (82411193, 'barrio Benimaclet', 'Benimaclet', 'Benimaclet', 39.4794236, -0.3571255, 1957, 11, 675, 'flat', 65, False, 1, 1, 'good', True, 1, 2802, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95752777, 'Calle de Sant Pius X', 'Jesús', 'Sant Marcellí', 39.4449977, -0.3881614, 3052, 3, 620, 'flat', 70, False, 3, 1, 'renew', False, 1, 6928, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95752602, 'barrio El Carme', 'Ciutat Vella', 'El Carme', 39.475017, -0.3829845, 656, 6, 1400, 'penthouse', 78, True, 2, 1, 'good', True, 1, 5075, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95752244, 'barrio El Mercat', 'Ciutat Vella', 'El Mercat', 39.4736662, -0.3790392999999999, 322, 3, 1500, 'flat', 92, True, 2, 2, 'good', True, 1, 4776, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95751671, 'barrio La Petxina', 'Extramurs', 'La Petxina', 39.4738927, -0.3880204, 975, 1, 1200, 'flat', 65, True, 2, 1, 'good', True, 1, 5523, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95751360, 'Calle del Pare Rico', 'Extramurs', 'La Petxina', 39.4731234, -0.3872934, 891, 3, 720, 'flat', 81, True, 3, 1, 'good', True, 1, 5480, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95748088, 'Avenida del Puerto, 109', 'Camins al Grau', 'Aiora', 39.4649943, -0.3488944, 2526, 3, 800, 'penthouse', 50, True, 2, 1, 'good', False, 1, 2925, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95741591, 'Calle Pintor Peiró', 'El Pla del Real', 'Exposició', 39.4764371, -0.3658385, 1142, 2, 1200, 'flat', 90, True, 2, 2, 'good', True, 1, 3602, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95738471, 'Calle de Don Juan de Austria', 'Ciutat Vella', 'Sant Francesc', 39.4685961, -0.3744862, 367, 2, 750, 'flat', 50, True, 1, 2, 'good', True, 1, 4573, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95736076, 'Avenida de Burjassot', 'La Saïdia', 'Marxalenes', 39.4839727, -0.3842536, 1550, 2, 845, 'flat', 81, True, 3, 1, 'good', True, 1, 5090, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95735852, 'Calle Salvador Perles s/n', 'Jesús', 'Sant Marcellí', 39.4428574, -0.3911715, 3362, 1, 720, 'flat', 85, True, 3, 2, 'good', True, 1, 7278, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95735706, 'barrio El Mercat', 'Ciutat Vella', 'El Mercat', 39.4738674, -0.3791578, 346, 4, 1700, 'flat', 83, True, 2, 2, 'good', True, 1, 4780, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95735682, 'Calle Santa Genoveva Torres, 2', 'Rascanya', 'Sant Llorenç', 39.4949131, -0.3617223, 2961, 7, 999, 'flat', 100, True, 3, 2, 'good', True, 1, 3393, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95733247, 'Calle de Vicent Sancho Tello', 'El Pla del Real', 'Mestalla', 39.4677239, -0.3576157, 1726, 5, 750, 'flat', 75, True, 2, 1, 'good', True, 1, 3320, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94779007, 'Calle Don Juan de Austria', 'Ciutat Vella', 'Sant Francesc', 39.4691189, -0.3742555999999999, 339, 3, 630, 'studio', 52, True, 0, 1, 'good', True, 1, 4533, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94210159, "Calle del Comte d\'Altea, 34", "L\'Eixample", \'Gran Vía\', 39.4663975, -0.3666353, 1050, 4, 850, \'flat\', 90, True, 4, 2, \'good\', True, 1, 4063, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (92070684, 'barrio Sant Francesc', 'Ciutat Vella', 'Sant Francesc', 39.4676907, -0.3785716999999999, 398, 2, 900, 'flat', 43, False, 2, 1, 'good', True, 1, 4936, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91755682, 'Plaza Poeta Badenes', 'Quatre Carreres', 'Na Rovella', 39.4575976, -0.3617757, 2005, 6, 1200, 'flat', 100, True, 2, 2, 'good', True, 1, 4293, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91237308, \'barrio Gran Vía\', "L\'Eixample", \'Gran Vía\', 39.4636187, -0.3690636, 1090, 1, 850, \'flat\', 80, True, 2, 1, \'good\', True, 1, 4397, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89727388, 'barrio Sant Francesc', 'Ciutat Vella', 'Sant Francesc', 39.468499, -0.3767694, 294, 9, 2000, 'flat', 60, True, 1, 1, 'good', True, 1, 4759, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95668208, 'barrio El Cabanyal-El Canyamelar', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4716041, -0.3296933999999999, 4081, 2, 1250, 'penthouse', 100, True, 3, 1, 'good', False, 1, 1406, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95659700, 'barrio El Cabanyal-El Canyamelar', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4615679, -0.3325272999999999, 3982, 1, 1000, 'flat', 90, True, 2, 1, 'good', False, 1, 2547, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95654534, 'barrio Malilla', 'Quatre Carreres', 'Malilla', 39.4572386, -0.3743315, 1563, 2, 950, 'flat', 94, True, 2, 2, 'good', True, 1, 5161, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95614955, 'barrio La Seu', 'Ciutat Vella', 'La Seu', 39.4769104, -0.3774864, 643, 4, 800, 'flat', 38, True, 1, 1, 'good', False, 1, 4573, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95568845, 'barrio En Corts', 'Quatre Carreres', 'En Corts', 39.457772, -0.3709637, 1579, 2, 1000, 'penthouse', 60, True, 1, 2, 'good', False, 1, 4891, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95568276, 'barrio La Petxina', 'Extramurs', 'La Petxina', 39.4701091, -0.3912613, 1209, 6, 1200, 'flat', 65, True, 1, 1, 'good', True, 1, 5890, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95543183, 'Calle Periodista Badía', 'El Pla del Real', 'Exposició', 39.4786152, -0.3631532, 1468, 1, 800, 'flat', 80, True, 2, 1, 'good', True, 1, 3328, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95525691, 'Calle de la Reina', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4717998, -0.3292685999999999, 4117, 2, 790, 'flat', 67, True, 3, 1, 'good', False, 1, 1375, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95760185, 'barrio Ciutat Fallera', 'Benicalap', 'Ciutat Fallera', 39.4983628, -0.3956766, 3417, 2, 750, 'flat', 90, False, 4, 2, 'good', True, 1, 6285, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95715217, 'barrio Penya-Roja', 'Camins al Grau', 'Penya-Roja', 39.4650684, -0.3587439, 1724, 2, 660, 'flat', 63, True, 2, 1, 'good', True, 1, 3566, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95207292, 'Calle Escultor José Capuz', 'Quatre Carreres', 'Mont-Olivet', 39.4597598, -0.3633655, 1736, 4, 970, 'flat', 100, True, 2, 2, 'good', True, 1, 4239, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89289756, 'Calle de la Sénia', 'Ciutat Vella', 'El Mercat', 39.4737849, -0.3774036, 296, 1, 1929, 'flat', 67, False, 2, 2, 'good', False, 1, 4636, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95720720, 'Calle de Trinitarios', 'Ciutat Vella', 'La Xerea', 39.4756305, -0.3701687999999999, 786, 2, 1100, 'flat', 100, True, 2, 2, 'good', True, 1, 3984, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95733267, \'Gran Vía del Marqués del Turia, 4\', "L\'Eixample", \'Gran Vía\', 39.4651604, -0.3724736999999999, 778, 1, 800, \'flat\', 70, True, 1, 1, \'good\', True, 1, 4572, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95732381, 'Calle Molinell', 'La Saïdia', 'Trinitat', 39.4834675, -0.3695198, 1524, 3, 650, 'flat', 88, True, 3, 1, 'good', True, 1, 3826, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95694356, 'Calle Santiago Rusiñol, 26', 'Rascanya', 'Els Orriols', 39.4952037, -0.3666338999999999, 2827, 3, 800, 'flat', 85, True, 3, 1, 'good', True, 1, 3799, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (34117979, 'Avenida del doctor waksman, 35', 'Quatre Carreres', 'En Corts', 39.4562873, -0.3717512, 1715, 10, 800, 'flat', 87, True, 3, 2, 'good', True, 1, 5044, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (35017601, \'Avenida jacinto benavente, 5\', "L\'Eixample", \'Gran Vía\', 39.4680537, -0.3639679999999999, 1188, 4, 1150, \'flat\', 89, True, 2, 2, \'good\', True, 1, 3775, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95596194, 'Calle de la Reina', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4701981, -0.3298587, 4067, 2, 790, 'flat', 70, True, 3, 1, 'good', False, 1, 1560, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95593845, \'Calle de Colón\', "L\'Eixample", \'El Pla del Remei\', 39.46955, -0.36787, 822, 1, 1000, \'flat\', 73, True, 2, 2, \'good\', True, 1, 4007, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95593562, 'Paseo Alameda', 'Camins al Grau', 'Penya-Roja', 39.4546755, -0.3441045, 3381, 3, 750, 'flat', 68, True, 1, 1, 'good', True, 1, 3624, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95560332, 'Calle Arquitecto Alfaro s/n', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4641452, -0.335024, 3705, 1, 1400, 'flat', 78, True, 3, 1, 'good', False, 1, 2341, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95515474, 'Calle de Just Vilar', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4674775, -0.3314689, 3949, 1, 580, 'flat', 70, True, 3, 1, 'good', False, 1, 1890, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91709217, \'Gran Via del Marqués del Túria\', "L\'Eixample", \'Gran Vía\', 39.4660604, -0.3739736999999999, 628, 1, 800, \'flat\', 70, False, 1, 1, \'good\', True, 1, 4644, 0, 0, True, 0, True)',
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95495798, \'Calle de Ciscar\', "L\'Eixample", \'Gran Vía\', 39.4662614, -0.3662007, 1090, 5, 1600, \'penthouse\', 94, False, 2, 2, \'good\', True, 1, 4038, 0, 0, True, 0, True)',
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95235390, \'jeronima gales\', \'Jesús\', "L\'Hort de Senabre", 39.4490425, -0.3941361, 2851, 5, 600, \'flat\', 80, True, 3, 1, \'good\', True, 1, 7082, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89890085, 'San Martín, 7', 'Ciutat Vella', 'Sant Francesc', 39.4733586, -0.3752827999999999, 299, 2, 850, 'studio', 50, True, 0, 1, 'good', True, 1, 4471, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (90132883, 'Avenida de les Corts Valencianes, 46', 'Benicalap', 'Benicalap', 39.4937972, -0.4009959999999999, 3242, 2, 600, 'studio', 30, True, 0, 1, 'good', True, 1, 6623, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89891542, 'Ribera, 13', 'Ciutat Vella', 'Sant Francesc', 39.4679602, -0.3757086, 375, 3, 1200, 'studio', 50, True, 0, 1, 'renew', True, 1, 4696, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93832407, 'ernesto anastacio', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4631366, -0.3336324, 3846, 3, 700, 'flat', 75, True, 1, 1, 'good', True, 1, 2406, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (90132879, 'Avenida de les Corts Valencianes, 46', 'Benicalap', 'Benicalap', 39.4937972, -0.4009959999999999, 3242, 2, 690, 'flat', 50, True, 1, 1, 'good', True, 1, 6623, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (39254167, 'Calle de la Cruz Roja', 'Patraix', 'Vara de Quart', 39.4594224, -0.4135604, 3378, 2, 750, 'duplex', 65, True, 1, 1, 'good', True, 1, 8073, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95740814, 'Paseo alameda', 'Camins al Grau', 'Penya-Roja', 39.4581423, -0.3514412, 2643, 3, 750, 'flat', 80, True, 1, 1, 'good', True, 1, 3641, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95107042, \'Calle del Almirante Cadarso, 30\', "L\'Eixample", \'Gran Vía\', 39.464169, -0.3674614, 1141, 7, 650, \'penthouse\', 30, True, 1, 1, \'good\', True, 1, 4247, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95732932, 'Pedro Cabanes', 'Rascanya', 'Torrefiel', 39.4954765, -0.3752302999999999, 2713, 2, 600, 'flat', 80, True, 2, 1, 'good', True, 1, 4510, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95732721, 'Calle Carrícola', 'Jesús', 'La Creu Coberta', 39.4526211, -0.3890713, 2294, 2, 650, 'flat', 70, True, 2, 1, 'good', True, 1, 6501, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95644068, 'TAPINERIA, 6', 'Ciutat Vella', 'La Seu', 39.4743092, -0.3764479, 360, 4, 900, 'duplex', 83, True, 1, 1, 'good', True, 1, 4543, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95614656, 'Calle de Salvador Pau s/n', 'Camins al Grau', 'Albors', 39.4707267, -0.3535374, 2034, 1, 850, 'flat', 100, True, 3, 1, 'good', True, 1, 2847, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94437477, 'Calle de Xàtiva', 'Extramurs', 'La Roqueta', 39.4690831, -0.3771617, 226, 5, 650, 'flat', 50, True, 1, 1, 'good', True, 1, 4768, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95517007, 'Calle Pintor Pascual Capuz', 'Patraix', 'Patraix', 39.46215, -0.39636, 1920, 1, 730, 'flat', 70, True, 2, 2, 'good', True, 1, 6583, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94318830, 'Calle del mar', 'Ciutat Vella', 'La Xerea', 39.4752634, -0.3740073, 537, 5, 600, 'flat', 50, True, 1, 1, 'good', True, 1, 4315, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95427818, 'Calle Arquitecto Alfaro', 'Poblats Marítims', 'El Grau', 39.4631873, -0.3340894, 3807, 1, 1400, 'flat', 80, True, 3, 1, 'good', True, 1, 2413, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95427410, "Calle de l\'Hospital, 22", \'Ciutat Vella\', \'El Pilar\', 39.4710536, -0.3823374, 437, 3, 700, \'flat\', 55, True, 2, 2, \'good\', True, 1, 5124, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95414951, 'Paseo de la Alameda', 'Camins al Grau', 'Penya-Roja', 39.4558712, -0.3427179999999999, 3414, 3, 750, 'flat', 67, True, 1, 1, 'good', True, 1, 3451, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95385238, \'barrio Russafa\', "L\'Eixample", \'Russafa\', 39.464709, -0.3743395, 755, 3, 725, \'flat\', 55, True, 1, 1, \'good\', False, 1, 4737, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95166059, 'Carricola', 'Jesús', 'La Creu Coberta', 39.4522742, -0.3849569, 2198, 2, 650, 'flat', 70, True, 2, 1, 'good', True, 1, 6226, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94942347, 'Calle de Pere Aleixandre', 'Quatre Carreres', 'Mont-Olivet', 39.4599315, -0.3612915, 1849, 3, 670, 'flat', 74, True, 2, 1, 'good', True, 1, 4090, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93512229, 'Avenida del Mestre Rodrigo', 'Campanar', 'Sant Pau', 39.4857088, -0.4049193, 2876, 13, 895, 'flat', 95, True, 2, 2, 'good', True, 1, 6868, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95756312, \'Av. del Cid\', "L\'Olivereta", \'Tres Forques\', 39.4702215, -0.3994757, 1911, 4, 750, \'flat\', 85, True, 3, 1, \'good\', True, 1, 6571, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95752523, 'barrio Penya-Roja', 'Camins al Grau', 'Penya-Roja', 39.4584279, -0.3525772, 2544, 7, 1000, 'flat', 97, True, 3, 2, 'good', True, 1, 3678, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95741733, 'Calle Pintor Peiró', 'El Pla del Real', 'Exposició', 39.4759371, -0.3657384999999999, 1122, 4, 900, 'flat', 60, True, 1, 1, 'good', True, 1, 3606, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88608099, 'Calle Mayor Nazaret', 'Poblats Marítims', 'Natzaret', 39.4493965, -0.3347691, 4373, 1, 625, 'flat', 78, True, 3, 1, 'good', False, 1, 3908, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95645862, 'barrio En Corts', 'Quatre Carreres', 'En Corts', 39.4517389, -0.3712208999999999, 2216, 7, 950, 'flat', 100, True, 4, 1, 'good', True, 1, 5331, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94198529, 'Calle del Conde de Montornes', 'Ciutat Vella', 'La Xerea', 39.4748642, -0.3707851, 692, 1, 750, 'flat', 60, True, 1, 1, 'good', True, 1, 4056, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95619368, 'barrio El Cabanyal-El Canyamelar', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4727383, -0.3310424999999999, 3968, 2, 2000, 'flat', 50, True, 2, 1, 'good', False, 1, 1327, 0, 0, True, 0, True)",
# ...
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95399144, 'Calle de Méndez Núñez', 'Poblats Marítims', 'El Grau', 39.4574934, -0.3358219, 3864, 0, 540, 'flat', 51, True, 2, 1, 'good', False, 1, 3061, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88166168, 'Calle de Sant Jacint Castanyeda', 'Quatre Carreres', 'Mont-Olivet', 39.458223, -0.3624732, 1914, 5, 530, 'flat', 46, True, 1, 1, 'good', False, 1, 4291, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94605689, 'Calle de la Reina', 'Poblats Marítims', 'El Cabanyal-El Canyamelar', 39.4757653, -0.3286099, 4205, 2, 700, 'flat', 83, True, 3, 1, 'good', True, 1, 937, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95220775, "Calle de l\'Arquitecte Ribes", "L\'Olivereta", \'Soternes\', 39.473382, -0.4050876, 2403, 2, 600, \'flat\', 80, True, 2, 1, \'good\', True, 1, 6975, 0, 0, True, 0, True)',
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95173906, "Calle de l\'Agró", "L\'Olivereta", \'La Fontsanta\', 39.4657885, -0.4095689999999999, 2837, 3, 610, \'flat\', 96, True, 3, 1, \'good\', True, 1, 7533, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95149043, 'Calle del Lugre', 'La Saïdia', 'Tormos', 39.4912708, -0.3830656, 2295, 4, 630, 'flat', 69, True, 3, 1, 'good', True, 1, 5059, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95058116, 'Calle Andreu Alfaro', 'Benicalap', 'Ciutat Fallera', 39.4988443, -0.3967811, 3509, 3, 700, 'flat', 82, True, 3, 2, 'good', True, 1, 6391, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95015619, 'Calle Rio Cenia', 'Poblats Marítims', 'Natzaret', 39.45447, -0.33496, 4074, 3, 530, 'flat', 69, True, 2, 1, 'good', False, 1, 3363, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94938636, 'Calle de Alquerías de les Bellver', 'Benicalap', 'Benicalap', 39.4929114, -0.3953433999999999, 2878, 1, 620, 'flat', 59, True, 3, 1, 'good', True, 1, 6128, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94911170, 'Calle del Duc de Mandas', 'Rascanya', 'Els Orriols', 39.4951693, -0.3700302, 2744, 5, 660, 'flat', 78, True, 3, 2, 'good', True, 1, 4074, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94826766, 'Calle de Sant Pius X', 'Jesús', 'Sant Marcellí', 39.4449628, -0.3915507, 3157, 3, 620, 'flat', 68, True, 3, 1, 'good', True, 1, 7161, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93512228, 'Avenida del Mestre Rodrigo', 'Campanar', 'Sant Pau', 39.4851088, -0.4056192999999999, 2889, 6, 1195, 'flat', 100, True, 3, 2, 'good', True, 1, 6926, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93512206, 'Avenida del Mestre Rodrigo', 'Campanar', 'Sant Pau', 39.4870088, -0.4029193, 2824, 3, 765, 'flat', 54, True, 1, 1, 'good', True, 1, 6703, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94616782, "Calle de l\'Erudit Orellana", \'Extramurs\', \'Arrancapins\', 39.4721107, -0.3882836, 954, 5, 760, \'flat\', 99, False, 3, 1, \'good\', True, 1, 5588, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94459805, 'Calle de Carrícola', 'Jesús', 'La Creu Coberta', 39.4530087, -0.3886686, 2240, 5, 620, 'flat', 76, True, 3, 1, 'good', True, 1, 6449, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94129521, 'Calle de Manuel Melià i Fuster', 'Benicalap', 'Nou Benicalap', 39.4988152, -0.3919203, 3326, 1, 640, 'flat', 62, False, 1, 1, 'good', True, 1, 5988, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (94101806, 'Calle de Godofred Ros', 'Quatre Carreres', 'Mont-Olivet', 39.4592285, -0.3596101, 2009, 4, 560, 'flat', 74, False, 3, 1, 'good', False, 1, 4033, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95261689, 'Avenida de Burjassot', 'La Saïdia', 'Marxalenes', 39.4859517, -0.383523, 1734, 5, 850, 'flat', 70, True, 2, 2, 'good', True, 1, 5034, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93414300, 'Calle de Salvador Giner', 'Ciutat Vella', 'El Carme', 39.4788865, -0.3782328, 867, 1, 1065, 'flat', 93, True, 3, 2, 'good', True, 1, 4605, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93068807, 'Calle Turia, 63', 'Extramurs', 'El Botànic', 39.4776778, -0.3855404, 1019, 5, 1733, 'penthouse', 91, True, 2, 2, 'good', True, 1, 5244, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (93068699, 'Calle Turia, 63', 'Extramurs', 'El Botànic', 39.4776778, -0.3855404, 1019, 5, 1733, 'penthouse', 95, True, 2, 2, 'good', True, 1, 5244, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89710149, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 2, 1678, 'duplex', 79, True, 2, 2, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89707000, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 1, 1403, 'flat', 63, True, 1, 1, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89706317, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 2, 1293, 'flat', 53, True, 1, 1, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89705355, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 2, 1568, 'flat', 86, True, 2, 1, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88425744, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 0, 1403, 'duplex', 72, True, 1, 1, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88425561, 'Calle Huertos, 4', 'Ciutat Vella', 'El Carme', 39.4799078, -0.3803264, 1012, 0, 1568, 'duplex', 86, True, 2, 2, 'good', True, 1, 4772, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (84116278, 'Bailén, 2', 'Extramurs', 'La Roqueta', 39.4674007, -0.3777897, 416, 1, 1200, 'flat', 85, True, 3, 2, 'good', True, 1, 4885, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (89056905, 'Calle del Padre Urbano', 'La Saïdia', 'Sant Antoni', 39.4875937, -0.3702878, 1926, 5, 775, 'flat', 99, True, 2, 1, 'good', True, 1, 3915, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (28563137, \'Calle Carlos Cervera\', "L\'Eixample", \'Russafa\', 39.4650576, -0.3726117, 782, 4, 630, \'flat\', 75, True, 2, 1, \'good\', True, 1, 4587, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (88618780, 'Calle de La Marina Baja s/n', 'Campanar', 'Sant Pau', 39.4905034, -0.4042217999999999, 3163, 3, 850, 'flat', 81, True, 1, 1, 'good', True, 1, 6846, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95730064, 'Camino Moncada', 'Rascanya', 'Torrefiel', 39.4918435, -0.3776021, 2304, 3, 675, 'flat', 74, True, 2, 1, 'good', True, 1, 4609, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91895518, 'Calle del Triador', 'Ciutat Vella', 'El Pilar', 39.4744733, -0.3838835, 681, 3, 680, 'flat', 60, True, 3, 2, 'good', False, 1, 5162, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95706062, 'Calle Uruguai', 'Jesús', 'La Raiosa', 39.4571042, -0.3850629, 1697, 5, 700, 'flat', 100, True, 3, 2, 'good', True, 1, 5949, 0, 0, True, 0, True)",
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (95703884, 'Calle Domingo Gómez', 'Rascanya', 'Torrefiel', 39.4913001, -0.3774569, 2243, 1, 600, 'flat', 90, True, 3, 1, 'good', True, 1, 4585, 0, 0, True, 0, True)",
#  'INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91830583, \'Gran Via del Marqués del Túria\', "L\'Eixample", \'Gran Vía\', 39.4632604, -0.3721737, 976, 1, 800, \'flat\', 70, False, 1, 1, \'good\', True, 1, 4648, 0, 0, True, 0, True)',
#  "INSERT INTO home (propertyCode, address, district, neighborhood, latitude, longitude, distance, floor, price, propertyType, size, exterior, rooms, bathrooms, status, hasLift, idCity, distanceBeach, internet, safety, zonaTranquila, score, available) VALUES (91336053, 'Calle Rascaña', 'Campanar', 'Campanar', 39.4829835, -0.3976012, 2189, 3, 650, 'flat', 91, True, 3, 1, 'good', True, 1, 6237, 0, 0, True, 0, True)",
#  ...]

# %%
import codecs

colums = ', '.join(home_valencia_df.columns)
with codecs.open(os.path.join(DATA_PATH, 'home_valencia.sql'), "w", "utf-8") as sql_file:
    for index, row in home_valencia_df.iterrows():
        sql_file.write("INSERT INTO home (" + colums + ") VALUES " + str(tuple(row.values)) + ";\n")

# %% [markdown]
# ## Generar INSERTs tabla city

# %%
'''
CREATE TABLE IF NOT EXISTS city (
  idCity INTEGER PRIMARY KEY,
  city VARCHAR(50),
  idCountry INTEGER, 
  province VARCHAR(50),
  weather NUMERIC(18,7),
  safety SMALLINT,
  avgCost NUMERIC(18,2),
  fun SMALLINT,
  cooworking BOOLEAN,
  sharemobility BOOLEAN,
  cyclingfriendly BOOLEAN,
  publicTransport BOOLEAN, 
  score INTEGER
);
'''

# INSERT INTO city (idCity, city, idCountry, province, weather, safety, avgCost, fun, cooworking, sharemobility, cyclingfriendly, publicTransport, score)
# VALUES (1, 'Valencia', 1, 'Valencia', 18.0, 4, 2180, 4, True, True, True, True, 5);
